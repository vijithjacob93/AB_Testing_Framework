# %% [markdown]
# #### Import Module

# %%
from ab_testing_framework import ab_testing_framework

# %% [markdown]
# #### Create an object of class ab_testing_framework with relevant parameters.

# %%
a = ab_testing_framework(desired_mde=0.02, metric_baseline=0.7, num_tails = 1, weekly_treatment_size = 650, weekly_control_size = 650)
# Required parameters: desired_mde, metric_baseline, any one combination of (total_treatment_size, weekly_treatment_size) x (weekly_control_size,total_control_size)

# %% [markdown]
# #### Display all current values of the properties

# %%
print(a.__dict__)
# Out:
# {'max_num_weeks': 24, 'weekly_treatment_size': 650, 'weekly_control_size': 650, 'total_treatment_size': 0, 'total_control_size': 0, 'num_tails': 1, 'desired_mde': 0.02, 'metric_baseline': 0.7, 'alpha': 0.05, 'beta': 0.8}

# %% [markdown]
# #### Next, solve the equation for the minimum detectable effect achieved week over week using the mde_solve method

# %%
a.mde_solve()
# Out:
#     num_weeks       mde  desired_mde
# 0           1  0.063205         0.02
# 1           2  0.044693         0.02
# 2           3  0.036491         0.02
# 3           4  0.031603         0.02
# 4           5  0.028266         0.02
# 5           6  0.025803         0.02
# 6           7  0.023889         0.02
# 7           8  0.022346         0.02
# 8           9  0.021068         0.02
# 9          10  0.019987         0.02
# 10         11  0.019057         0.02
# 11         12  0.018246         0.02
# 12         13  0.017530         0.02
# 13         14  0.016892         0.02
# 14         15  0.016319         0.02
# 15         16  0.015801         0.02
# 16         17  0.015329         0.02
# 17         18  0.014898         0.02
# 18         19  0.014500         0.02
# 19         20  0.014133         0.02
# 20         21  0.013792         0.02
# 21         22  0.013475         0.02
# 22         23  0.013179         0.02

# %% [markdown]
# #### Visualize mde achieved over the number of weeks the test is run

# %%
a.plot_mde_over_time()

# %% [markdown]
# #### Properties can be updated and rerun

# %%
a.desired_mde=0.04
a.metric_baseline=0.6
a.num_tails=2
a.alpha=0.05
a.weekly_treatment_size = 100
a.total_control_size = 1000

a.mde_solve()

a.plot_mde_over_time()
